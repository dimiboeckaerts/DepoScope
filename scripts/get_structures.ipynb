, 481, 4440, 1571, 4365, 5054, 5649, 4764, 3800, 5192, 4552, 5983, 1471, 834, 3909, 1566, 1857, 4783, 5092, 5155, 5704, 3955, 2963, 4772, 1856, 2669, 4945, 5410, 6361, 1513, 1523, 2779, 3906, 4229, 4634, 1658, 334, 1921, 5059, 4478, 4549, 225, 3767, 3952, 880, 5234, 2093, 4472, 4597, 5226, 6550, 5418, 5666, 5968, 3953, 6095, 466, 6271, 2659, 5091, 1997, 1470, 3930, 217, 1998, 2486, 1710, 6365, 1848, 5982, 1515, 4555, 3939, 5228, 6686, 5134, 5162, 5802, 1501, 3947, 3728, 4497, 5627, 6006, 6017, 5058, 6035, 1065, 2012, 2729, 1779, 5239, 6434, 2945, 4598, 1162, 2632, 3010, 2106, 1107, 1521, 164, 6458, 5053, 523, 1462, 3937, 3798, 5255, 6658, 3801, 1789, 5715, 1181, 6685, 1524, 2634, 2761, 4924, 1111, 3442, 4554, 5633, 6795, 5935, 3782, 5603]

# %%
# Get list of proteins :
path_work = "/home/conchae/ML_depolymerase/get_candidates/millard"


df = pd.read_csv(f"{path_work}/df_sequences.index.v3.csv", sep = "\t", names = ["index_seq", "name" ,"seq"])

prot_names = []

for _,row in df.iterrows() :
    if row["index_seq"] in good_indices :
        prot_names.append(row["name"])

# %%
import json 

dico_results = json.load(open(f"{path_work}/dbsuite_results.v3.json"))

ipr = set()
for prot in dico_results :
    if prot in prot_names :
        ipr.update([ipr_res.split(".")[0]])

# %% [markdown]
# ***
# # Homework

# %%
#import xmltodict
import pprint
import json
#from PPT_functions import *

#path_PFAM = "/home/robbyce/Documents/bioinformatics/Depolymerase_DB"
path_PFAM = "/media/concha-eloko/Linux/depolymerase_project"

xml_dico = json.load(open(f"{path_PFAM}/IR_description.EC.full.json"))

# %%
xml_dico
# Out:
# {'IPR002925': {'short_name': 'Dienelactn_hydro',
#   'description': 'Dienelactone hydrolases play a crucial role in chlorocatechol degradation via the modified ortho cleavage pathway. Enzymes induced in 4-fluorobenzoate-utilizing bacteria have been classified into three groups on the basis of their specificity towards cis- and trans-dienelactone .Some proteins contain repeated small fragments of this domain (for example rat kan-1 protein).'},
#  'IPR013217': {'short_name': 'Methyltransf_12',
# ...

# %%
good_ipr = {'IPR024429', 'IPR011840', 'IPR035396', 'IPR003476', 'IPR011330', 'IPR006775', 'IPR001223', 'IPR012939', 'IPR043534', 'IPR044112', 'IPR024428', 'IPR016286', 'IPR008929', 'IPR011838', 'IPR018082', 'IPR002022', 'IPR011040', 'IPR001329', 'IPR006101', 'IPR016714', 'IPR023295', 'IPR000556', 'IPR019563', 'IPR016455', 'IPR000322', 'IPR002594', 'IPR024535', 'IPR016282', 'IPR023346', 'IPR013189', 'IPR037398', 'IPR046372', 'IPR026283', 'IPR008585', 'IPR029456', 'IPR006633', 'IPR001286', 'IPR007724', 'IPR024561', 'IPR013776', 'IPR005201', 'IPR006047', 'IPR011395', 'IPR013148', 'IPR005198', 'IPR034641', 'IPR011583', 'IPR016590', 'IPR008811', 'IPR025975', 'IPR002152', 'IPR009860', 'IPR012970', 'IPR006710', 'IPR036278', 'IPR015179', 'IPR003790', 'IPR000933', 'IPR016840', 'IPR006626', 'IPR006215', 'IPR014895', 'IPR011837', 'IPR000743', 'IPR036881', 'IPR029411', 'IPR004197', 'IPR021865', 'IPR032091', 'IPR041351', 'IPR032312', 'IPR016283', 'IPR032792', 'IPR015177', 'IPR008979', 'IPR002037', 'IPR044914', 'IPR014718', 'IPR045032', 'IPR032979', 'IPR013785', 'IPR041624', 'IPR011100', 'IPR001362', 'IPR000757', 'IPR012334', 'IPR029070', 'IPR005604', 'IPR000400', 'IPR014635', 'IPR001439', 'IPR017069', 'IPR001139', 'IPR038901', 'IPR036434', 'IPR022844', 'IPR025706', 'IPR006421', 'IPR039743', 'IPR039448', 'IPR006584', 'IPR036439', 'IPR044505', 'IPR045857', 'IPR000514', 'IPR006046', 'IPR016007', 'IPR016289', 'IPR040527', 'IPR002925', 'IPR000726', 'IPR001661', 'IPR036962', 'IPR031330', 'IPR013777', 'IPR001000', 'IPR015883', 'IPR044846', 'IPR015331', 'IPR031335', 'IPR002252', 'IPR041542', 'IPR002241', 'IPR011839', 'IPR039174', 'IPR005200', 'IPR000125', 'IPR035669', 'IPR011050', 'IPR024430', 'IPR036026', 'IPR012878', 'IPR016828', 'IPR003159', 'IPR006103', 'IPR008397', 'IPR000677', 'IPR015289', 'IPR016287', 'IPR013830', 'IPR026856', 'IPR038970', 'IPR001724', 'IPR013775', 'IPR007781', 'IPR027946', 'IPR039279', 'IPR039513', 'IPR011683', 'IPR010905', 'IPR039473', 'IPR037110', 'IPR023933', 'IPR000805', 'IPR023296', 'IPR024200'}

# %%
import pprint
pp = pprint.PrettyPrinter(width = 150)

depo_terms = ["hyluronidase", "pectin", "pectate","sialidase", "levanase", "xylosidase","dextranase","rhamnosidase","alginate", "polysaccharide"]
# add hydrolase later
for ipr in xml_dico :
    for term in depo_terms : 
        if xml_dico[ipr]["description"].count(term) > 0 :
            print(ipr)
            pp.pprint(xml_dico[ipr])
            print("\n")
            break
# Out:
# IPR029411
# {'description': 'This is domain III of rhamnogalacturonan lyase (RG-lyase). The full-length protein specifically recognises and cleaves alpha-1,4 '
#                 'glycosidic bonds between l-rhamnose and d-galacturonic acids in the backbone of rhamnogalacturonan-I, a major component of the '
#                 'plant cell wall polysaccharide, pectin. This domain possesses a jelly roll β-sandwich fold structurally homologous to carbohydrate '
#                 'binding modules (CBMs), and it carries two sulfate ions and a hexa-coordinated calcium ion .',
#  'short_name': 'RG-lyase_III'}
#
#
# IPR011330
# {'description': 'This superfamily represents a structural domain found in glycoside hydrolase families 38 ( e.g. alpha-mannosidase) and 57 ( e.g. '
#                 '4-alpha-glucanotransferase, N-terminal) as well as in NodB-like polysaccharide deacetylase and in some hypothetical proteins (e.g. '
# ...
